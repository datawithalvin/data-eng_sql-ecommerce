# %%
from sqlalchemy import create_engine
from sqlalchemy.exc import OperationalError

import psycopg2
from psycopg2 import OperationalError

import pandas as pd

# %%
def create_db_connection():
    """
    Create a database connection and return the connection object
    Returns:
        connection: SQLAlchemy connection object if connection is successful, None otherwise
    """
    try:
        engine = create_engine('postgresql://postgres:superadmin@localhost:5432/db-ecommerce')
        engine.connect()
        print("Connection to PostgreSQL DB successful")
    except OperationalError as e:
        print("Error occurred during connection:", e)
        connection = None

    return engine

# test connection
connection = create_db_connection()
# Out:
# Connection to PostgreSQL DB successful

# %%
def create_conn():
    """
    Create a database connection and return the connection object
    Returns:
        connection: psycopg2 connection object if connection is successful, None otherwise
    """
    conn = None
    try:
        conn = psycopg2.connect(
            database="db-ecommerce",
            user="postgres",
            password="superadmin",
            host="localhost",
            port="5432",
        )
        print("Connection to PostgreSQL DB successful")
    except OperationalError as e:
        print(f"The error '{e}' occurred")
    return conn

engine = create_conn()
# Out:
# Connection to PostgreSQL DB successful

# %%
def query_data_from_db(engine, query):
    """
    Select data from a database using a given SQL query
    Args:
        connection: A connection object
        query (str): SQL query
    Returns:
        df: A dataframe containing the selected data
    """
    df = None
    try:
        df = pd.read_sql_query(query, con=engine)
        print("Data fetched successfully.")
    except Exception as e:
        print(f"Error occurred during data fetching: {e}")
    return df

# %%
query = """
    SELECT 
        table_name, column_name, data_type 
    FROM 
        information_schema.columns
    WHERE 
        table_schema = 'public'
    ORDER BY 
        table_name, ordinal_position;
"""
table_df = query_data_from_db(engine, query)

table_df
# Out:
# Data fetched successfully.
# C:\Users\PF2L6BL6\AppData\Local\Temp\ipykernel_3600\3581240349.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, con=engine)
#              table_name                column_name          data_type
# 0   product_information                sku_product  character varying
# 1   product_information               product_name  character varying
# 2   product_information                ordered_qty            integer
# 3   product_information                  stock_lvl            integer
# 4   product_information       restocking_lead_time            integer
# 5   product_information            sentiment_score               real
# 6   product_information        sentiment_magnitude               real
# 7          product_list                sku_product  character varying
# 8          product_list            product_name_v2  character varying
# 9   transaction_records          id_unique_visitor  character varying
# 10  transaction_records              channel_group  character varying
# 11  transaction_records                  hits_time  character varying
# 12  transaction_records        geo_network_country  character varying
# 13  transaction_records           geo_network_city  character varying
# 14  transaction_records  total_transaction_revenue               real
# 15  transaction_records     number_of_transactions            integer
# 16  transaction_records                 time_spent            integer
# 17  transaction_records                 page_views            integer
# 18  transaction_records                       date               date
# 19  transaction_records                   id_visit  character varying
# 20  transaction_records                  hits_type  character varying
# 21  transaction_records      product_refund_amount               real
# 22  transaction_records                product_qty            integer
# 23  transaction_records              product_price               real
# 24  transaction_records            product_revenue               real
# 25  transaction_records                sku_product  character varying
# 26  transaction_records            product_name_v2  character varying
# 27  transaction_records        product_category_v2  character varying
# 28  transaction_records            product_variant  character varying
# 29  transaction_records         item_currency_code  character varying
# 30  transaction_records                   item_qty            integer
# 31  transaction_records               item_revenue               real
# 32  transaction_records        transaction_revenue               real
# 33  transaction_records             transaction_id  character varying
# 34  transaction_records                 page_title  character varying
# 35  transaction_records        page_search_keyword  character varying
# 36  transaction_records            page_path_lvl_1  character varying

# %%
query = """
    SELECT 
        *
    FROM 
        transaction_records;
"""
table_df = query_data_from_db(engine, query)

table_df
# Out:
# Data fetched successfully.
# C:\Users\PF2L6BL6\AppData\Local\Temp\ipykernel_3600\3581240349.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, con=engine)
# Empty DataFrame
# Columns: [id_unique_visitor, channel_group, hits_time, geo_network_country, geo_network_city, total_transaction_revenue, number_of_transactions, time_spent, page_views, date, id_visit, hits_type, product_refund_amount, product_qty, product_price, product_revenue, sku_product, product_name_v2, product_category_v2, product_variant, item_currency_code, item_qty, item_revenue, transaction_revenue, transaction_id, page_title, page_search_keyword, page_path_lvl_1]
# Index: []
#
# [0 rows x 28 columns]

# %%
# load csv files for each table
df_products = pd.read_csv("../raw-datasets/products.csv")
df_productlist = pd.read_csv("../raw-datasets/product_list.csv")
df_transactions = pd.read_csv("../raw-datasets/rev_transactions.csv")

# displaying each dataframe
display(df_products.head(3), df_productlist.head(3), df_transactions.head(3))
# Out:
#                SKU                                 name  orderedQuantity  \
# 0  GGADFBSBKS42347                   PC gaming speakers                0
# 1     GGOEGAAX0581         Women's Colorblock Tee White                0
# 2     GGOEGAAX0596   Men's Quilted Insulated Vest Black               26
#
#    stockLevel  restockingLeadTime  sentimentScore  sentimentMagnitude
# 0         100                   1             NaN                 NaN
# 1           0                   8             0.8                 2.0
# 2          32                   8             0.8                 2.0
#        productSKU v2ProductName
# 0        10 55401      Lip Balm
# 1         9180842      Maze Pen
# 2  GGOEGGOA017399      Maze Pen
#          fullVisitorId channelGrouping  hits_time geoNetwork_country  \
# 0  7851878234225373633  Organic Search    1819831               Peru
# 1  7851878234225373633  Organic Search    1819831               Peru
# 2  7851878234225373633  Organic Search    1819831               Peru
#
#   geoNetwork_city  totals_totalTransactionRevenue  totals_transactions  \
# 0     La Victoria                        42000000                    1
# 1     La Victoria                        42000000                    1
# 2     La Victoria                        42000000                    1
#
#    totals_timeOnSite  totals_pageviews      date  ...  \
# 0               1834                40  20160807  ...
# 1               1834                40  20160807  ...
# 2               1834                40  20160807  ...
#
#    hits_product_v2ProductCategory hits_product_productVariant  \
# 0                       (not set)                        BLUE
# 1                       (not set)          Single Option Only
# 2                       (not set)                       GREEN
#
#    hits_item_currencyCode  hits_item_itemQuantity  hits_item_itemRevenue  \
# 0                     USD                     NaN                    NaN
# 1                     USD                     NaN                    NaN
# 2                     USD                     NaN                    NaN
#
#    hits_transaction_transactionRevenue hits_transaction_transactionId  \
# 0                             42000000                 ORD20160807983
# 1                             42000000                 ORD20160807983
# 2                             42000000                 ORD20160807983
#
#      hits_page_pageTitle hits_page_searchKeyword hits_page_pagePathLevel1
# 0  Checkout Confirmation                     NaN     /ordercompleted.html
# 1  Checkout Confirmation                     NaN     /ordercompleted.html
# 2  Checkout Confirmation                     NaN     /ordercompleted.html
#
# [3 rows x 28 columns]

# %%
# displaying information for each dataframe
display(df_products.info(), df_productlist.info(), df_transactions.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SKU                 1092 non-null   object
#  1   name                1092 non-null   object
#  2   orderedQuantity     1092 non-null   int64
#  3   stockLevel          1092 non-null   int64
#  4   restockingLeadTime  1092 non-null   int64
#  5   sentimentScore      1091 non-null   float64
#  6   sentimentMagnitude  1091 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 59.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2273 entries, 0 to 2272
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   productSKU     2273 non-null   object
#  1   v2ProductName  2273 non-null   object
# dtypes: object(2)
# memory usage: 35.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   fullVisitorId                        20000 non-null  uint64
#  1   channelGrouping                      20000 non-null  object
#  2   hits_time                            20000 non-null  int64
#  3   geoNetwork_country                   20000 non-null  object
#  4   geoNetwork_city                      20000 non-null  object
#  5   totals_totalTransactionRevenue       20000 non-null  int64
#  6   totals_transactions                  20000 non-null  int64
#  7   totals_timeOnSite                    20000 non-null  int64
#  8   totals_pageviews                     20000 non-null  int64
#  9   date                                 20000 non-null  int64
#  10  visitId                              20000 non-null  int64
#  11  hits_type                            20000 non-null  object
#  12  hits_product_productRefundAmount     0 non-null      float64
#  13  hits_product_productQuantity         19999 non-null  float64
#  14  hits_product_productPrice            19999 non-null  float64
#  15  hits_product_productRevenue          19999 non-null  float64
#  16  hits_product_productSKU              19999 non-null  object
#  17  hits_product_v2ProductName           19999 non-null  object
#  18  hits_product_v2ProductCategory       19999 non-null  object
#  19  hits_product_productVariant          19999 non-null  object
#  20  hits_item_currencyCode               20000 non-null  object
#  21  hits_item_itemQuantity               0 non-null      float64
#  22  hits_item_itemRevenue                0 non-null      float64
#  23  hits_transaction_transactionRevenue  20000 non-null  int64
#  24  hits_transaction_transactionId       20000 non-null  object
#  25  hits_page_pageTitle                  20000 non-null  object
#  26  hits_page_searchKeyword              0 non-null      float64
#  27  hits_page_pagePathLevel1             20000 non-null  object
# dtypes: float64(7), int64(8), object(12), uint64(1)
# memory usage: 4.3+ MB
# None
# None
# None

# %%
# rename columns from each dataframe so it will matched with the columns name in the tables
df_products = df_products.rename(columns={
    'SKU':'sku_product', 'name':'product_name', 'orderedQuantity':'ordered_qty', 'stockLevel':'stock_lvl', 'restockingLeadTime':'restocking_lead_time',
    'sentimentScore':'sentiment_score', 'sentimentMagnitude':'sentiment_magnitude'
})

df_productlist = df_productlist.rename(columns={
    'productSKU':'sku_product', 'v2ProductName':'product_name_v2'
})

df_transactions = df_transactions.rename(columns={
    'fullVisitorId':'id_unique_visitor', 'channelGrouping':'channel_group', 'geoNetwork_country':'geo_network_country',
       'geoNetwork_city':'geo_network_city', 'totals_totalTransactionRevenue':'total_transaction_revenue',
       'totals_transactions':'number_of_transactions', 'totals_timeOnSite':'time_spent', 'totals_pageviews':'page_views',
       'visitId':'id_visit', 'hits_type':'hits_type', 'hits_product_productRefundAmount':'product_refund_amount',
       'hits_product_productQuantity':'product_qty', 'hits_product_productPrice':'product_price',
       'hits_product_productRevenue':'product_revenue', 'hits_product_productSKU':'sku_product',
       'hits_product_v2ProductName':'product_name_v2', 'hits_product_v2ProductCategory':'product_category_v2',
       'hits_product_productVariant':'product_variant', 'hits_item_currencyCode':'item_currency_code',
       'hits_item_itemQuantity':'item_qty', 'hits_item_itemRevenue':'item_revenue',
       'hits_transaction_transactionRevenue':'transaction_revenue', 'hits_transaction_transactionId':'transaction_id',
       'hits_page_pageTitle':'page_title', 'hits_page_searchKeyword':'page_search_keyword',
       'hits_page_pagePathLevel1':'page_path_lvl_1'
})



display(df_products.head(3), df_productlist.head(3), df_transactions.head(3))
# Out:
#        sku_product                         product_name  ordered_qty  \
# 0  GGADFBSBKS42347                   PC gaming speakers            0
# 1     GGOEGAAX0581         Women's Colorblock Tee White            0
# 2     GGOEGAAX0596   Men's Quilted Insulated Vest Black           26
#
#    stock_lvl  restocking_lead_time  sentiment_score  sentiment_magnitude
# 0        100                     1              NaN                  NaN
# 1          0                     8              0.8                  2.0
# 2         32                     8              0.8                  2.0
#       sku_product product_name_v2
# 0        10 55401        Lip Balm
# 1         9180842        Maze Pen
# 2  GGOEGGOA017399        Maze Pen
#      id_unique_visitor   channel_group  hits_time geo_network_country  \
# 0  7851878234225373633  Organic Search    1819831                Peru
# 1  7851878234225373633  Organic Search    1819831                Peru
# 2  7851878234225373633  Organic Search    1819831                Peru
#
#   geo_network_city  total_transaction_revenue  number_of_transactions  \
# 0      La Victoria                   42000000                       1
# 1      La Victoria                   42000000                       1
# 2      La Victoria                   42000000                       1
#
#    time_spent  page_views      date  ...  product_category_v2  \
# 0        1834          40  20160807  ...            (not set)
# 1        1834          40  20160807  ...            (not set)
# 2        1834          40  20160807  ...            (not set)
#
#       product_variant  item_currency_code  item_qty  item_revenue  \
# 0                BLUE                 USD       NaN           NaN
# 1  Single Option Only                 USD       NaN           NaN
# 2               GREEN                 USD       NaN           NaN
#
#    transaction_revenue  transaction_id             page_title  \
# 0             42000000  ORD20160807983  Checkout Confirmation
# 1             42000000  ORD20160807983  Checkout Confirmation
# 2             42000000  ORD20160807983  Checkout Confirmation
#
#   page_search_keyword       page_path_lvl_1
# 0                 NaN  /ordercompleted.html
# 1                 NaN  /ordercompleted.html
# 2                 NaN  /ordercompleted.html
#
# [3 rows x 28 columns]

# %%
def rename_columns(csv_file, df):
    """
    Renames columns of the DataFrame based on the loaded CSV file.

    Args:
        csv_file (str): Path of the loaded CSV file.
        df (pandas.DataFrame): DataFrame to be renamed.

    Returns:
        pandas.DataFrame: DataFrame with renamed columns.
    """
    if csv_file == '../raw-datasets/products.csv':
        df = df.rename(columns={
            'SKU': 'sku_product',
            'name': 'product_name',
            'orderedQuantity': 'ordered_qty',
            'stockLevel': 'stock_lvl',
            'restockingLeadTime': 'restocking_lead_time',
            'sentimentScore': 'sentiment_score',
            'sentimentMagnitude': 'sentiment_magnitude'
        })

    elif csv_file == '../raw-datasets/product_list.csv':
        df = df.rename(columns={
            'productSKU': 'sku_product',
            'v2ProductName': 'product_name_v2'
        })

    elif csv_file == '../raw-datasets/rev_transactions.csv':
        df = df.rename(columns={
            'fullVisitorId': 'id_unique_visitor',
            'channelGrouping': 'channel_group',
            'geoNetwork_country': 'geo_network_country',
            'geoNetwork_city': 'geo_network_city',
            'totals_totalTransactionRevenue': 'total_transaction_revenue',
            'totals_transactions': 'number_of_transactions',
            'totals_timeOnSite': 'time_spent',
            'totals_pageviews': 'page_views',
            'visitId': 'id_visit',
            'hits_type': 'hits_type',
            'hits_product_productRefundAmount': 'product_refund_amount',
            'hits_product_productQuantity': 'product_qty',
            'hits_product_productPrice': 'product_price',
            'hits_product_productRevenue': 'product_revenue',
            'hits_product_productSKU': 'sku_product',
            'hits_product_v2ProductName': 'product_name_v2',
            'hits_product_v2ProductCategory': 'product_category_v2',
            'hits_product_productVariant': 'product_variant',
            'hits_item_currencyCode': 'item_currency_code',
            'hits_item_itemQuantity': 'item_qty',
            'hits_item_itemRevenue': 'item_revenue',
            'hits_transaction_transactionRevenue': 'transaction_revenue',
            'hits_transaction_transactionId': 'transaction_id',
            'hits_page_pageTitle': 'page_title',
            'hits_page_searchKeyword': 'page_search_keyword',
            'hits_page_pagePathLevel1': 'page_path_lvl_1'
        })

    return df

# %%
def insert_data_to_db(connection, csv_file, table_name):
    """
    Insert data from a CSV file into a database table using a given database connection
    Args:
        connection: A connection object
        csv_file (str): Path to the CSV file to be inserted
        table_name (str): Name of the database table into which data is to be inserted
    Returns:
        None
    """
    try:
        df = pd.read_csv(csv_file)
        # rename columns by calling the rename_columns function
        df = rename_columns(csv_file, df)
        
        # convert 'date' column to datetime if it exists
        if 'date' in df.columns:
            df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')

        # convert columns of type uint64 to string
        for col in df.columns:
            if df[col].dtype == 'uint64':
                df[col] = df[col].astype(str)

        # drop duplicates if 'sku_product' column exists
        if 'sku_product' in df.columns:
            df = df.drop_duplicates(subset='sku_product', keep='first')

        df.to_sql(table_name, connection, if_exists='append', index=False)
        print(f"Data inserted successfully into table {table_name}")
    except Exception as e:
        print(f"Error occurred during data insertion into table {table_name}:", e)

# %%
# set dictionary
csv_files_and_tables = {
    '../raw-datasets/products.csv': 'product_information',
    '../raw-datasets/product_list.csv': 'product_list',
    '../raw-datasets/rev_transactions.csv': 'transaction_records',
}

# insert the data into the table
for csv_file, table_name in csv_files_and_tables.items():
    insert_data_to_db(connection, csv_file, table_name)
# Out:
# Data inserted successfully into table product_information
# Data inserted successfully into table product_list
# Data inserted successfully into table transaction_records

# %%
transaction_query = "SELECT * FROM transaction_records LIMIT 100;"
transaction_df = query_data_from_db(engine, transaction_query)

transaction_df
# Out:
# Data fetched successfully.
# C:\Users\PF2L6BL6\AppData\Local\Temp\ipykernel_3600\3581240349.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, con=engine)
#       id_unique_visitor   channel_group hits_time geo_network_country  \
# 0   7851878234225373633  Organic Search   1819831                Peru
# 1   7851878234225373633  Organic Search   1819831                Peru
# 2   7851878234225373633  Organic Search   1819831                Peru
# 3   7851878234225373633  Organic Search   1819831                Peru
# 4   7851878234225373633  Organic Search   1819831                Peru
# ..                  ...             ...       ...                 ...
# 95  3490941383536951175          Direct   3105868               Japan
# 96  1246338221591989045        Referral   2198455               Japan
# 97  1246338221591989045        Referral   2198455               Japan
# 98  6392388121934645207        Referral    815704               Japan
# 99  6392388121934645207        Referral    815704               Japan
#
#    geo_network_city  total_transaction_revenue  number_of_transactions  \
# 0       La Victoria                 42000000.0                       1
# 1       La Victoria                 42000000.0                       1
# 2       La Victoria                 42000000.0                       1
# 3       La Victoria                 42000000.0                       1
# 4       La Victoria                 42000000.0                       1
# ..              ...                        ...                     ...
# 95           Minato                 29100000.0                       1
# 96           Minato                102950000.0                       1
# 97           Minato                102950000.0                       1
# 98           Minato                 26350000.0                       1
# 99           Minato                 26350000.0                       1
#
#     time_spent  page_views        date  ... product_category_v2  \
# 0         1834          40  2016-08-07  ...           (not set)
# 1         1834          40  2016-08-07  ...           (not set)
# 2         1834          40  2016-08-07  ...           (not set)
# 3         1834          40  2016-08-07  ...           (not set)
# 4         1834          40  2016-08-07  ...           (not set)
# ..         ...         ...         ...  ...                 ...
# 95        3106          21  2017-05-23  ...            Headgear
# 96        2198          23  2017-05-25  ...             Apparel
# 97        2198          23  2017-05-25  ...             Apparel
# 98        1738          35  2017-05-30  ...             Apparel
# 99        1738          35  2017-05-30  ...                Waze
#
#        product_variant item_currency_code  item_qty  item_revenue  \
# 0                 BLUE                USD      None          None
# 1   Single Option Only                USD      None          None
# 2                GREEN                USD      None          None
# 3   Single Option Only                USD      None          None
# 4                  RED                USD      None          None
# ..                 ...                ...       ...           ...
# 95                 S/M                USD      None          None
# 96                 12M                USD      None          None
# 97                 18M                USD      None          None
# 98                  MD                USD      None          None
# 99  Single Option Only                USD      None          None
#
#     transaction_revenue   transaction_id             page_title  \
# 0            42000000.0   ORD20160807983  Checkout Confirmation
# 1            42000000.0   ORD20160807983  Checkout Confirmation
# 2            42000000.0   ORD20160807983  Checkout Confirmation
# 3            42000000.0   ORD20160807983  Checkout Confirmation
# 4            42000000.0   ORD20160807983  Checkout Confirmation
# ..                  ...              ...                    ...
# 95           29100000.0  ORD201705232232  Checkout Confirmation
# 96          102950000.0  ORD201705252263  Checkout Confirmation
# 97          102950000.0  ORD201705252263  Checkout Confirmation
# 98           26350000.0  ORD201705302342  Checkout Confirmation
# 99           26350000.0  ORD201705302342  Checkout Confirmation
#
#    page_search_keyword       page_path_lvl_1
# 0                 None  /ordercompleted.html
# 1                 None  /ordercompleted.html
# 2                 None  /ordercompleted.html
# 3                 None  /ordercompleted.html
# 4                 None  /ordercompleted.html
# ..                 ...                   ...
# 95                None  /ordercompleted.html
# 96                None  /ordercompleted.html
# 97                None  /ordercompleted.html
# 98                None  /ordercompleted.html
# 99                None  /ordercompleted.html
#
# [100 rows x 28 columns]

# %%
engine.close()

# %%
connection.dispose()
